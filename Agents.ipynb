# %% [markdown]
# # Table driven agent

# %% [markdown]
# Vaccum Cleaning Agent with locations A and B

# %%
# how many sensors? Ans: 2 (Location and, Condition)
# Location -> A or B
# Condition -> clean or dirty
# how many different perecept sequences? Ans: 4 (A,Clean) (A,Dirty) 
# ... (B,Clean) (B,Dirty)
# how many actions and what are the actions? 3 (Right, Left, and Suck)
# AGENT FUNCTION: map the percept sequences to actions

table={('A','Clean'):'Right',
       ('A','Dirty'):'Suck',
       ('B','Clean'):'Left',
       ('B','Dirty'):'Suck'}

percepts=[]  # to store percet sequence  
def table_driven_agent(percept):
    print('Perception Received: '+ str(percept))
    percepts.append(percept) # updating percept history
    action = lookup(percept,table) # searching for action
    return action

def lookup(percept,table):
    #for key in table:
    #    if key == percept:
    #        return table[key]
    return table[percept]

# lets simulate the agent
import random
Location = random.choice(['A','B'])
Condition = random.choice(['Clean','Dirty'])

while True: # to perceieve environment repeatedly
    action = table_driven_agent((Location, Condition))
    print('Action Performed: '+ action)
    cmd = input('Get Perception (yes/no): ')
    if(cmd == 'no' or cmd != 'yes'): break
    if action == 'Right':
        Location = 'B'
        Condition = random.choice(['Clean','Dirty'])
    elif action == 'Left':
        Location = 'A'
        Condition = random.choice(['Clean','Dirty'])
    else:
        Condition = 'Clean'

# %% [markdown]
# # Simple reflex agent

# %%
def simple_reflex_agent(percept):
    print('Perception Received: '+ str(percept))
    location = percept[0]
    status = percept[1]
    if status =='Dirty':
        action = 'Suck'
    elif location == 'A':
        action = 'Right'
    elif location =='B':
        action = 'Left'
    return action

import random
Location = random.choice(['A','B'])
Condition = random.choice(['Clean','Dirty'])

while True:
    action= simple_reflex_agent((Location,Condition))
    print('Action Performed: '+ action)
    cmd = input('Get Perception (yes/no): ')
    if(cmd == 'no' or cmd != 'yes'): break
    if action == 'Right':
        Location = 'B'
        Condition = random.choice(['Clean','Dirty'])
    elif action== 'Left':
        Location = 'A'
        Condition = random.choice(['Clean','Dirty'])
    else:
        Condition = 'Clean'
# Out:
# Perception Received: ('B', 'Dirty')
# Action Performed: Suck
# Get Perception (yes/no): yes
# Perception Received: ('B', 'Clean')
# Action Performed: Left
# Get Perception (yes/no): yes
# Perception Received: ('A', 'Dirty')
# Action Performed: Suck
# Get Perception (yes/no): no

# %% [markdown]
# # Model based agent

# %%
model = {'A':'Unknown', 'B':'Unknown'}
world_state = 'Bad'
action = 'Unknown'

def update_state(action, percept, model):
    location = percept[0]
    status = percept[1]
    model[location] = status #udate the model based on current perception
    
    global world_state
    if action == 'Suck':
        model[location]='Clean'
    if model['A']=='Clean' and model['B']=='Clean': # model checking
        world_state = 'Good'
    else:
        world_state = 'Bad'
    return world_state
        

def model_based_reflex_agent(percept):
    location = percept[0]
    status = percept[1]
    
    global world_state,action,model
    
    if world_state == 'Good':
        action = 'Pause'
        return action
    elif status == 'Dirty':
        action = 'Suck'
    elif location == 'A':
        action = 'Right'
    elif location == 'B':
        action = 'Left'
    world_state = update_state(action, percept, model)
    print('Perception: '+str(percept)) 
    print('Action Performed: '+ action)    
    print('Model: '+str(model))   
    print('State: '+str(world_state))    
    return action


import random
Location = random.choice(['A','B'])
Condition= random.choice(['Clean','Dirty'])

while True:
    print('*****')
    action = model_based_reflex_agent((Location,Condition))
    if action == 'Right':
        Location = 'B'
        Condition = random.choice(['Clean','Dirty'])
    elif action == 'Left':
        Location = 'A'
        Condition = random.choice(['Clean','Dirty'])
    elif action == 'Suck':
        Condition = 'Clean'
    elif action == 'Pause':
        cmd = input('Stopped. Do restart? (yes/no): ')
        if(cmd == 'no' or cmd != 'yes'): break
        Location = random.choice(['A','B'])
        Condition = random.choice(['Clean','Dirty'])
        model = {'A':'Unknown', 'B':'Unknown'}
        world_state = 'Bad'
        action = 'Unknown'
# Out:
# *****
# Perception: ('A', 'Clean')
# Action Performed: Right
# Model: {'A': 'Clean', 'B': 'Unknown'}
# State: Bad
# *****
# Perception: ('B', 'Dirty')
# Action Performed: Suck
# Model: {'A': 'Clean', 'B': 'Clean'}
# State: Good
# *****
# Stopped. Do restart? (yes/no): yes
# *****
# Perception: ('B', 'Dirty')
# Action Performed: Suck
# Model: {'A': 'Unknown', 'B': 'Clean'}
# State: Bad
# *****
# Perception: ('B', 'Clean')
# Action Performed: Left
# Model: {'A': 'Unknown', 'B': 'Clean'}
# State: Bad
# *****
# Perception: ('A', 'Dirty')
# Action Performed: Suck
# Model: {'A': 'Clean', 'B': 'Clean'}
# State: Good
# *****
# Stopped. Do restart? (yes/no): no

# %% [markdown]
# ## Task

# %% [markdown]
# Implement diffierent types of agent implementation to do certain task of your choice.
# 1. Table Driven Agent
# 2. Simple Reflex Agent
# 3. Model Based Agent

# %% [raw]
# PEAS desription
#
# Perecept sequences =>4 (Empty,Dirty),(Empty,Clean),(Full,Dirty),(Full,Clean)
#
# Agent Description:
# The aim of the agent is fill bottols automatically from  the filter. The bottol will be filled from the filter one by one. There will be two sensor. One for Water level checking weather the bottol is empty or full. Another one for checking whether the bottol is dirty or clean. If the bottol is empty and clean the bottol will be filled. If the bottol is filled and clean then it will be passed and another bottol will come. If the bottol is empty and dirty the bottol will be washed. If the bottol is filled and dirty then it will be removed from the system.
#
# List the actions: (Fill, Wash, Pass, Remove)
# List the sensors: 2

# %%
table={('Empty','Dirty'):'Wash',('Empty','Clean'):'Fill',('Full','Dirty'):'Remove',('Full','Clean'):'Pass'}
percepts=[]    
def table_driven_agent(percept):
    print('Perception Received: '+ str(percept))
    percepts.append(percept)
    action = lookup(percept,table)
    return action

def lookup(percept,table):
    for key in table:
        if key == percept:
            return table[key]
    #return table[percept]

import random
WaterLevel = random.choice(['Empty','Full'])
DirtyChecker = random.choice(['Dirty','Clean'])

while True:
    action= table_driven_agent((WaterLevel,DirtyChecker))
    print('Action Performed: '+ str(action))
    cmd = input('Get Perception (yes/no): ')
    if(cmd == 'no' or cmd != 'yes'): break
    if action == 'Pass':
        WaterLevel = 'Empty'
        DirtyChecker = random.choice(['Dirty','Clean'])
    elif action== 'Fill':
        WaterLevel = 'Full'
        DirtyChecker = random.choice(['Dirty','Clean']) 
    elif action== 'Remove':
        WaterLevel = 'Empty'
        DirtyChecker = random.choice(['Dirty','Clean']) 
    elif action== 'Wash':
        WaterLevel = 'Empty'
        DirtyChecker = random.choice(['Dirty','Clean']) 
    else:
        print('Action Can not Performe any more')
# Out:
# Perception Received: ('Empty', 'Clean')
# Action Performed: Fill
# Get Perception (yes/no): yes
# Perception Received: ('Full', 'Clean')
# Action Performed: Pass
# Get Perception (yes/no): yes
# Perception Received: ('Empty', 'Clean')
# Action Performed: Fill
# Get Perception (yes/no): yes
# Perception Received: ('Full', 'Clean')
# Action Performed: Pass
# Get Perception (yes/no): yes
# Perception Received: ('Empty', 'Clean')
# Action Performed: Fill
# Get Perception (yes/no): yes
# Perception Received: ('Full', 'Clean')
# Action Performed: Pass
# Get Perception (yes/no): yes
# Perception Received: ('Empty', 'Dirty')
# Action Performed: Wash
# Get Perception (yes/no): yes
# Perception Received: ('Empty', 'Clean')
# Action Performed: Fill
# Get Perception (yes/no): yes
# Perception Received: ('Full', 'Clean')
# Action Performed: Pass
# Get Perception (yes/no): no

# %%
def simple_reflex_agent(percept):
    print('Perception Received: '+ str(percept))
    level = percept[0]
    checker = percept[1]
    
    if (checker =='Dirty') and (level == 'Empty'):
        action = 'Wash'
    elif checker =='Dirty' and level == 'Full':
        action = 'Remove'
    elif checker =='Clean' and level == 'Empty':
        action = 'Fill'
    elif checker =='Clean' and level == 'Full':
        action = 'Pass'
    return action

import random
WaterLevel = random.choice(['Empty','Full'])
DirtyChecker = random.choice(['Dirty','Clean'])


while True:
    action= simple_reflex_agent((WaterLevel,DirtyChecker))
    print('Action Performed: '+ str(action))
    cmd = input('Get Perception (yes/no): ')
    if(cmd == 'no' or cmd != 'yes'): break
    if action == 'Pass':
        WaterLevel = 'Empty'
        DirtyChecker = random.choice(['Dirty','Clean'])
    elif action== 'Fill':
        WaterLevel = 'Full'
        DirtyChecker = random.choice(['Dirty','Clean']) 
    elif action== 'Remove':
        WaterLevel = 'Empty'
        DirtyChecker = random.choice(['Dirty','Clean']) 
    elif action== 'Wash':
        WaterLevel = 'Empty'
        DirtyChecker = random.choice(['Dirty','Clean']) 
    else:
        print('Action Can not Performe any more')
# Out:
# Perception Received: ('Empty', 'Dirty')
# Action Performed: Wash
# Get Perception (yes/no): yes
# Perception Received: ('Empty', 'Clean')
# Action Performed: Fill
# Get Perception (yes/no): yes
# Perception Received: ('Full', 'Dirty')
# Action Performed: Remove
# Get Perception (yes/no): yes
# Perception Received: ('Empty', 'Clean')
# Action Performed: Fill
# Get Perception (yes/no): yes
# Perception Received: ('Full', 'Clean')
# Action Performed: Pass
# Get Perception (yes/no): yes
# Perception Received: ('Empty', 'Dirty')
# Action Performed: Wash
# Get Perception (yes/no): yes
# Perception Received: ('Empty', 'Clean')
# Action Performed: Fill
# Get Perception (yes/no): no

# %%
model = {'Empty':'Undefine', 'Full':'Undefine'}
world_state = 'Bad'
action = 'Undefine'

def update_state(action, percept, model):
    level = percept[0]
    checker = percept[1]
    model[level] = checker
    
    global world_state
    if action == 'Remove'or action == 'Wash':
        model[level]='Clean'
    if model['Empty']=='Clean' and model['Full']=='Clean':
        world_state = 'Good'
    else:
        world_state = 'Bad'
    return world_state
        

def model_based_reflex_agent(percept):
    level = percept[0]
    checker = percept[1]
    
    global world_state,action,model
    
    if world_state == 'Good':
        action = 'Process is going ok'
        return action
    elif (checker =='Dirty') and (level == 'Empty'):
        action = 'Wash'
    elif checker =='Dirty' and level == 'Full':
        action = 'Remove'
    elif checker =='Clean' and level == 'Empty':
        action = 'Fill'
    elif checker =='Clean' and level == 'Full':
        action = 'Pass'
    world_state = update_state(action, percept, model)
    print('Perception: '+str(percept)) 
    print('Action Performed: '+ action)    
    print('Model: '+str(model))   
    print('State: '+str(world_state))    
    return action


import random
WaterLevel = random.choice(['Empty','Full'])
DirtyChecker = random.choice(['Dirty','Clean'])

while True:
    action = model_based_reflex_agent((WaterLevel,DirtyChecker))
    print('*****')
    if action == 'Pass':
        WaterLevel = 'Empty'
        DirtyChecker = random.choice(['Dirty','Clean'])
    elif action== 'Fill':
        WaterLevel = 'Full'
        DirtyChecker = random.choice(['Dirty','Clean']) 
    elif action== 'Remove':
        WaterLevel = 'Empty'
        DirtyChecker = random.choice(['Dirty','Clean']) 
    elif action== 'Wash':
        WaterLevel = 'Empty'
        DirtyChecker = random.choice(['Dirty','Clean']) 
    elif action == 'Process is going ok':
        cmd = input('Stopped. Do restart? (yes/no): ')
        if(cmd == 'no' or cmd != 'yes'): break
        DirtyChecker = random.choice(['Dirty','Clean'])
        model = {'Empty':'Undefine', 'Full':'Undefine'}
        world_state = 'Bad'
        action = 'Undefine'
# Out:
# Perception: ('Full', 'Dirty')
# Action Performed: Remove
# Model: {'Empty': 'Undefine', 'Full': 'Clean'}
# State: Bad
# *****
# Perception: ('Empty', 'Dirty')
# Action Performed: Wash
# Model: {'Empty': 'Clean', 'Full': 'Clean'}
# State: Good
# *****
# *****
# Stopped. Do restart? (yes/no): yes
# Perception: ('Empty', 'Dirty')
# Action Performed: Wash
# Model: {'Empty': 'Clean', 'Full': 'Undefine'}
# State: Bad
# *****
# Perception: ('Empty', 'Clean')
# Action Performed: Fill
# Model: {'Empty': 'Clean', 'Full': 'Undefine'}
# State: Bad
# *****
# Perception: ('Full', 'Clean')
# Action Performed: Pass
# Model: {'Empty': 'Clean', 'Full': 'Clean'}
# State: Good
# *****
# *****
# Stopped. Do restart? (yes/no): no
